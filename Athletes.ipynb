# %%
pays_dict = {
 'afghanistan': 'af',
    'albania': 'al',
    'algeria': 'dz',           
    'argentina': 'ar',
    'armenia': 'am',
    'australia': 'au',
    'australia / new zealand (australasia)': 'au/nz',
    'austria': 'at',
    'austria / united states of amerika': 'at/us',
    'azerbaijan': 'az',
    'bahamas': 'bs',
    'bahrain': 'bh',
    'barbados': 'bb',
    'belarus': 'by',
    'belgium': 'be',
    'bermuda': 'bm',
    'bohemia': 'cz',
    'bohemia / great britain': 'cz/gb',
    'botswana': 'bw',
    'brazil': 'br',
    'bulgaria': 'bg',
    'burkina-faso': 'bf',
    'burundi': 'bi',
    'cameroon': 'cm',         
    'canada': 'ca',
    'cape verde': 'cv',
    'chile': 'cl',
    'china': 'cn',
    'chinese taipei': 'tw',
    'colombia': 'co',
    'commonwealth of independent states': 'cis',
    'costa rica': 'cr',
    'cote divoire': 'ci',
    'croatia': 'hr',
    'cuba': 'cu',
    'cyprus': 'cy',
    'czech republic': 'cz',
    'czechoslovakia': 'cs',
    'denmark': 'dk',
    'djibouti': 'dj',
    'dominican': 'dm',
    'dominican republic': 'do',
    'ecuador': 'ec',
    'egypt': 'eg',
    'eritrea': 'er',
    'estonia': 'ee',
    'ethiopia': 'et',
    'federal republic of germany': 'de',
    'fiji': 'fj',
    'finland': 'fi',
    'france': 'fr',
    'france / great britain': 'fr/gb',
    'france / great britain / ireland': 'fr/gb/ie',
    'gabon': 'ga',
    'georgia': 'ge',
    'german democratic republic': 'dd',
    'germany': 'de',
    'ghana': 'gh',
    'great britain': 'gb',
    'great britain / australia': 'gb/au',
    'great britain / france / united states of america': 'gb/fr/us',
    'great britain / ireland': 'gb/ie',
    'great britain / ireland / germany': 'gb/ie/de',
    'greece': 'gr',
    'greece / belgium': 'gr/be',
    'grenada': 'gd',
    'guatemala': 'gt',
    'guyana': 'gy',
    'haiti': 'ht',
    'hong kong': 'hk',
    'hungary': 'hu',
    'iceland': 'is',
    'independent olympic participants': 'iop',
    'india': 'in',
    'individual neutral athletes': 'ina',
    'individual olympic athletes': 'ioa',
    'indonesia': 'id',
    'iran': 'ir',
    'iraq': 'iq',
    'ireland': 'ie',
    'israel': 'il',
    'italy': 'it',
    'jamaica': 'jm',
    'japan': 'jp',
    'japan / korea': 'jp/kr',
    'jordan': 'jo',         
    'kazakhstan': 'kz',
    'kenya': 'ke',
    'kosovo': 'xk',
    'kuwait': 'kw',
    'kyrgyzstan': 'kg',
    'latvia': 'lv',
    'lebanon': 'lb',
    'liechtenstein': 'li',
    'lithuania': 'lt',
    'luxembourg': 'lu',       
    'luxembourg / france': 'lu/fr',
    'malaysia': 'my',
    'mauritius': 'mu',
    'mexico': 'mx',
    'moldova': 'md',
    'mongolia': 'mn',
    'montenegro': 'me',
    'morocco': 'ma',         
    'mozambique': 'mz',
    'namibia': 'na',
    'netherlands': 'nl',
    'netherlands / france': 'nl/fr',
    'netherlands antilles': 'an',
    'new zealand': 'nz',
    'niger': 'ne',
    'nigeria': 'ng',
    'north korea': 'kp',     
    'north-macedonia': 'mk',
    'norway': 'no',
    'pakistan': 'pk',
    'panama': 'pa',
    'paraguay': 'py',
    'peru': 'pe',
    'philippines': 'ph',
    'poland': 'pl',
    'portugal': 'pt',
    'puerto rico': 'pr',     
    'qatar': 'qa',        
    'refugee olympic team': 'rot',
    'romania': 'ro',
    'russia': 'ru',
    'russian olympic committee': 'roc',
    'saint lucia': 'lc',     
    'samoa': 'ws',
    'san marino': 'sm',   
    'saudi arabia': 'sa',     
    'senegal': 'sn',
    'serbia': 'rs',
    'serbia montenegro': 'cs',
    'singapore': 'sg',
    'slovakia': 'sk',
    'slovenia': 'si',
    'smyrna': 'tr',
    'south africa': 'za',
    'south korea': 'kr',
    'soviet union': 'su',
    'spain': 'es',
    'sri lanka': 'lk',
    'sudan': 'sd',
    'suriname': 'sr',
    'sweden': 'se',
    'sweden / denmark': 'se/dk',
    'switzerland': 'ch',
    'syria': 'sy',           
    'tajikistan': 'tj',      
    'tanzania': 'tz',
    'thailand': 'th',
    'thessalonika': 'gr',
    'togo': 'tg',
    'tonga': 'to',
    'trinidad & tobago': 'tt',
    'tunisia': 'tn',         
    'turkey': 'tr',
    'turkmenistan': 'tm',
    'uganda': 'ug',          
    'ukraine': 'ua',
    'united arab emirates': 'ae', 
    'united states of america': 'us',
    'united states of america / cuba': 'us/cu',
    'united states of america / france': 'us/fr',
    'united states of america / germany': 'us/de',
    'united states of america / great britain': 'us/gb',
    'united states of america / mexico': 'us/mx',
    'uruguay': 'uy',       
    'uzbekistan': 'uz',      
    'venezuela': 've',
    'vietnam': 'vn',
    'virgin islands': 'vi',
    'west indies federation': 'wif',
    'yugoslavia': 'yu',
    'zambia': 'zm',
    'zimbabwe': 'zw'
}

# Correction de la duplication de la clé 'de'
# Remarque: Il y a une duplication dans le dictionnaire d'origine (de = Germany et de = Allemagne)
# Nous gardons la version française pour harmoniser
pays_dict['de'] = "Allemagne"

print(f"Nombre de pays dans le dictionnaire: {len(pays_dict)}")
# Out:
# Nombre de pays dans le dictionnaire: 179

# %%
#ATHLETES

from bs4 import BeautifulSoup
import requests
import json
import re

pays_dict = {
    'afghanistan': 'af',
    'albania': 'al',
    'algeria': 'dz',         
    'argentina': 'ar',
    'armenia': 'am',
    'australia': 'au',
    'australia / new zealand (australasia)': 'au/nz',
    'austria': 'at',
    'austria / united states of amerika': 'at/us',
    'azerbaijan': 'az',
    'bahamas': 'bs',
    'bahrain': 'bh',
    'barbados': 'bb',
    'belarus': 'by',
    'belgium': 'be',
    'bermuda': 'bm',
    'bohemia': 'cz',
    'bohemia / great britain': 'cz/gb',
    'botswana': 'bw',
    'brazil': 'br',
    'bulgaria': 'bg',
    'burkina-faso': 'bf',
    'burundi': 'bi',
    'cameroon': 'cm',         
    'canada': 'ca',
    'cape verde': 'cv',
    'chile': 'cl',
    'china': 'cn',
    'chinese taipei': 'tw',
    'colombia': 'co',
    'commonwealth of independent states': 'cis',
    'costa rica': 'cr',
    'cote divoire': 'ci',
    'croatia': 'hr',
    'cuba': 'cu',
    'cyprus': 'cy',
    'czech republic': 'cz',
    'czechoslovakia': 'cs',
    'denmark': 'dk',
    'djibouti': 'dj',
    'dominican': 'dm',
    'dominican republic': 'do',
    'ecuador': 'ec',
    'egypt': 'eg',
    'eritrea': 'er',
    'estonia': 'ee',
    'ethiopia': 'et',
    'federal republic of germany': 'de',
    'fiji': 'fj',
    'finland': 'fi',
    'france': 'fr',
    'france / great britain': 'fr/gb',
    'france / great britain / ireland': 'fr/gb/ie',
    'gabon': 'ga',
    'georgia': 'ge',
    'german democratic republic': 'dd',
    'germany': 'de',
    'ghana': 'gh',
    'great britain': 'gb',
    'great britain / australia': 'gb/au',
    'great britain / france / united states of america': 'gb/fr/us',
    'great britain / ireland': 'gb/ie',
    'great britain / ireland / germany': 'gb/ie/de',
    'greece': 'gr',
    'greece / belgium': 'gr/be',
    'grenada': 'gd',
    'guatemala': 'gt',
    'guyana': 'gy',
    'haiti': 'ht',
    'hong kong': 'hk',
    'hungary': 'hu',
    'iceland': 'is',
    'independent olympic participants': 'iop',
    'india': 'in',
    'individual neutral athletes': 'ina',
    'individual olympic athletes': 'ioa',
    'indonesia': 'id',
    'iran': 'ir',
    'iraq': 'iq',
    'ireland': 'ie',
    'israel': 'il',
    'italy': 'it',
    'jamaica': 'jm',
    'japan': 'jp',
    'japan / korea': 'jp/kr',
    'jordan': 'jo',         
    'kazakhstan': 'kz',
    'kenya': 'ke',
    'kosovo': 'xk',
    'kuwait': 'kw',
    'kyrgyzstan': 'kg',
    'latvia': 'lv',
    'lebanon': 'lb',
    'liechtenstein': 'li',
    'lithuania': 'lt',
    'luxembourg': 'lu',       
    'luxembourg / france': 'lu/fr',
    'malaysia': 'my',
    'mauritius': 'mu',
    'mexico': 'mx',
    'moldova': 'md',
    'mongolia': 'mn',
    'montenegro': 'me',
    'morocco': 'ma',         
    'mozambique': 'mz',
    'namibia': 'na',
    'netherlands': 'nl',
    'netherlands / france': 'nl/fr',
    'netherlands antilles': 'an',
    'new zealand': 'nz',
    'niger': 'ne',
    'nigeria': 'ng',
    'north korea': 'kp',     
    'north-macedonia': 'mk',
    'norway': 'no',
    'pakistan': 'pk',
    'panama': 'pa',
    'paraguay': 'py',
    'peru': 'pe',
    'philippines': 'ph',
    'poland': 'pl',
    'portugal': 'pt',
    'puerto rico': 'pr',     
    'qatar': 'qa',        
    'refugee olympic team': 'rot',
    'romania': 'ro',
    'russia': 'ru',
    'russian olympic committee': 'roc',
    'saint lucia': 'lc',     
    'samoa': 'ws',
    'san marino': 'sm',   
    'saudi arabia': 'sa',     
    'senegal': 'sn',
    'serbia': 'rs',
    'serbia montenegro': 'cs',
    'singapore': 'sg',
    'slovakia': 'sk',
    'slovenia': 'si',
    'smyrna': 'tr',
    'south africa': 'za',
    'south korea': 'kr',
    'soviet union': 'su',
    'spain': 'es',
    'sri lanka': 'lk',
    'sudan': 'sd',
    'suriname': 'sr',
    'sweden': 'se',
    'sweden / denmark': 'se/dk',
    'switzerland': 'ch',
    'syria': 'sy',           
    'tajikistan': 'tj',      
    'tanzania': 'tz',
    'thailand': 'th',
    'thessalonika': 'gr',
    'togo': 'tg',
    'tonga': 'to',
    'trinidad & tobago': 'tt',
    'tunisia': 'tn',         
    'turkey': 'tr',
    'turkmenistan': 'tm',
    'uganda': 'ug',          
    'ukraine': 'ua',
    'united arab emirates': 'ae', 
    'united states of america': 'us',
    'united states of america / cuba': 'us/cu',
    'united states of america / france': 'us/fr',
    'united states of america / germany': 'us/de',
    'united states of america / great britain': 'us/gb',
    'united states of america / mexico': 'us/mx',
    'uruguay': 'uy',       
    'uzbekistan': 'uz',      
    'venezuela': 've',
    'vietnam': 'vn',
    'virgin islands': 'vi',
    'west indies federation': 'wif',
    'yugoslavia': 'yu',
    'zambia': 'zm',
    'zimbabwe': 'zw'
}

# Création d'un dictionnaire inversé pour recherche par code
codes_pays_dict = {v: k for k, v in pays_dict.items()}

def extract_basic_info(person, pays_dict):
    """Extrait les informations de base d'un élément HTML d'athlète"""
    # Extraire l'URL du profil et l'ID de l'athlète
    link = person.get('href')
    athlete_id = None
    if link:
        id_match = re.search(r'/olympic-athlete/[^/]+/(\d+)', link)
        if id_match:
            athlete_id = id_match.group(1)
    
    # Extraire le prénom et le nom
    prenom_div = person.select_one('div.vn')
    nom_div = person.select_one('div.n')
    prenom = prenom_div.get_text(strip=True) if prenom_div else ""
    nom = nom_div.get_text(strip=True) if nom_div else ""
    
    # Extraire le pays
    flag_img = person.select_one('img[src*="flagge"]')
    pays = flag_img.get('alt') if flag_img and flag_img.get('alt') else ""
    
    # Si le pays est vide, essayer d'extraire à partir du nom de fichier
    if not pays and flag_img and flag_img.get('src'):
        src = flag_img.get('src')
        pays_code = src.split('/')[-1].split('.')[0]
        # Remplacer le code pays par le nom complet s'il existe dans le dictionnaire inversé
        pays = codes_pays_dict.get(pays_code.lower(), pays_code)
    
    # Extraire le sexe
    sexe = ""
    if person.select_one('svg.female'):
        sexe = 'female'
    elif person.select_one('svg.male'):
        sexe = 'male'
    
    # Créer le dictionnaire de l'utilisateur
    user = {
        'id': athlete_id,
        'prenom': prenom,
        'nom': nom,
        'pays': pays,
        'sexe': sexe,
        'profile_url': f"https://olympics-statistics.com{link}" if link else "",
        'medailles': {
            'nombre': 0,
            'types': [],
            'sport': ""
        }
    }
    
    return user

def extract_medal_info(profile_url):
    """Extrait les informations de médailles depuis l'URL du profil d'un athlète"""
    try:
        response = requests.get(profile_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Initialisation
        nombre_medailles = 0
        types_medailles = []
        sport = ""
        
        # Trouver les divs de médailles
        medals = soup.select('.deck .medaille.visible')
        nombre_medailles = len(medals)
        
        for medal in medals:
            # Type de médaille (1: or, 2: argent, 3: bronze)
            medal_div = medal.select_one('.the-medal')
            if medal_div and medal_div.has_attr('data-medal'):
                code = medal_div['data-medal']
                if code == '1':
                    types_medailles.append("or")
                elif code == '2':
                    types_medailles.append("argent")
                elif code == '3':
                    types_medailles.append("bronze")
            
            # Sport
            sport_div = medal.select_one('.m-sport')
            if sport_div:
                sport = sport_div.text.strip()
        
        return {
            'nombre': nombre_medailles,
            'types': types_medailles,
            'sport': sport
        }
    except Exception as e:
        print(f"Erreur lors de l'extraction des médailles pour {profile_url}: {str(e)}")
        return {
            'nombre': 0,
            'types': [],
            'sport': ""
        }

def main():
    # URL principale pour la liste des athlètes
    main_url = "https://olympics-statistics.com/olympic-athletes"
    
    try:
        # Récupérer la page principale
        response = requests.get(main_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extraire les cartes d'athlètes - cette fois nous allons directement chercher les liens
        athletes_links = soup.select('a.card.athlet.visible')
        
        print(f"Nombre d'athlètes trouvés: {len(athletes_links)}")
        
        users = []
        for i, athlete_link in enumerate(athletes_links):
            print(f"Traitement de l'athlète {i+1}/{len(athletes_links)}")
            
            # Extraire les informations de base avec le dictionnaire des pays
            user = extract_basic_info(athlete_link, pays_dict)
            
            if user['profile_url']:
                # Obtenir les informations de médailles
                medals_info = extract_medal_info(user['profile_url'])
                user['medailles'] = medals_info
                
                users.append(user)
                print(f"  - {user['prenom']} {user['nom']} (ID: {user['id']}) de {user['pays']} ajouté avec succès")
            else:
                print(f"  - Impossible de traiter l'athlète, URL du profil manquante")
        
        # Sauvegarder dans un fichier JSON
        output_file = "athletes.json"
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(users, f, ensure_ascii=False, indent=4)
        
        print(f"Informations sauvegardées pour {len(users)} athlètes dans {output_file}")
        
#         # Aperçu
#         from pprint import pprint
#         print("\nAperçu du premier athlète:")
#         if users:
#             pprint(users[0])
    
    except Exception as e:
        print(f"Erreur lors de l'exécution du script: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Erreur lors de l'exécution du script: HTTPSConnectionPool(host='olympics-statistics.com', port=443): Max retries exceeded with url: /olympic-athletes (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000026CB7B3BBE0>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu'))

# %%
import json
import pandas as pd
import numpy as np

try:
    with open('athletes.json', 'r', encoding='utf-8') as f:
        athletes = json.load(f)
    print(f"Données chargées : {len(athletes)} athlètes trouvés")
except FileNotFoundError:
    print("Fichier athletes.json introuvable. Exécutez d'abord le script principal.")
    athletes = []

# Conversion en DataFrame pour faciliter le nettoyage
df = pd.DataFrame(athletes)

# Aperçu initial
print("\nAperçu avant nettoyage:")
print(df.head())
print(f"Colonnes: {df.columns.tolist()}")

# Fonction pour extraire les types de médailles en colonnes distinctes
def nettoyer_data():
    if len(df) == 0:
        print("Pas de données à nettoyer.")
        return df
    
    # Création de colonnes pour chaque type de médaille
    df['or'] = df['medailles'].apply(lambda x: x['types'].count('or') if isinstance(x, dict) and 'types' in x else 0)
    df['argent'] = df['medailles'].apply(lambda x: x['types'].count('argent') if isinstance(x, dict) and 'types' in x else 0)
    df['bronze'] = df['medailles'].apply(lambda x: x['types'].count('bronze') if isinstance(x, dict) and 'types' in x else 0)
    
    # Extraction du sport principal
    df['sport'] = df['medailles'].apply(lambda x: x['sport'] if isinstance(x, dict) and 'sport' in x else "")
    
    # Vérification et correction des données manquantes
    df['prenom'] = df['prenom'].fillna('')
    df['nom'] = df['nom'].fillna('')
    df['pays'] = df['pays'].fillna('Inconnu')
    
    # Ajout d'une colonne nom complet
    df['nom_complet'] = df['prenom'] + ' ' + df['nom']
    
    # Résolution des problèmes de pays
    # 1. Uniformisation des noms de pays (en français)
    pays_uniformes = {
        'United States': 'États-Unis',
        'Great Britain': 'Grande-Bretagne',
        'United Kingdom': 'Royaume-Uni',
        'France': 'France',
        'Germany': 'Allemagne',  # Déjà corrigé dans le dict mais au cas où
        'South Korea': 'Corée du Sud',
        'Russia': 'Russie'
        # Ajoutez d'autres conversions si nécessaire
    }
    
    for old_name, new_name in pays_uniformes.items():
        df.loc[df['pays'] == old_name, 'pays'] = new_name
    
    # 2. Vérification des codes pays non résolus (si un code à 2 lettres subsiste)
    pays_non_resolus = df[df['pays'].str.len() == 2]['pays'].unique()
    if len(pays_non_resolus) > 0:
        print(f"ATTENTION: Codes pays non résolus: {', '.join(pays_non_resolus)}")
    
    # Suppression de la colonne medailles (puisque nous avons extrait les informations)
    df_clean = df.drop(columns=['medailles'])
    
    # Statistiques post-nettoyage
#     print("\nStatistiques après nettoyage:")
#     print(f"Nombre total d'athlètes: {len(df_clean)}")
#     print(f"Nombre d'athlètes avec médailles d'or: {df_clean['or'].sum()}")
#     print(f"Nombre d'athlètes avec médailles d'argent: {df_clean['argent'].sum()}")
#     print(f"Nombre d'athlètes avec médailles de bronze: {df_clean['bronze'].sum()}")
#     print(f"Nombre de pays représentés: {df_clean['pays'].nunique()}")
#     print(f"Sports représentés: {df_clean['sport'].nunique()}")
    
#     # Top 5 des pays avec le plus d'athlètes
#     print("\nTop 5 des pays avec le plus d'athlètes:")
#     print(df_clean['pays'].value_counts().head())
    
    # Sauvegarde du DataFrame nettoyé
    
    
    # Conversion du DataFrame en liste de dictionnaires (format original)
    athletes_clean_dict = df_clean.to_dict(orient='records')

    # Enregistrement dans un fichier JSON avec une indentation pour meilleure lisibilité
    with open('athletes_clean.json', 'w', encoding='utf-8') as f:
        json.dump(athletes_clean_dict, f, ensure_ascii=False, indent=4)

    print(f"Données nettoyées enregistrées au format JSON dans 'athletes_clean.json'")
    print(f"Nombre d'athlètes enregistrés: {len(athletes_clean_dict)}")

    # Aperçu du premier élément
    print("\nAperçu du premier athlète au format JSON:")
    print(json.dumps(athletes_clean_dict[0], ensure_ascii=False, indent=2))
    
    
    # df_clean.to_csv('athletes_clean.csv', index=False)
    # df_clean.to_excel('athletes_clean.xlsx', index=False)
    
    print("\nDonnées nettoyées sauvegardées dans athletesjsd")
    
    return df_clean

# Exécution du nettoyage
df_clean = nettoyer_data()

# Aperçu final
print("\nAperçu après nettoyage:")
print(df_clean.head())
# Out:
# Données chargées : 1216 athlètes trouvés
#
# Aperçu avant nettoyage:
#       id     prenom       nom           pays    sexe  \
# 0  25024   Jennifer      Azzi  United States  female
# 1  31553       Sera     Azuma          Japan  female
# 2  27117  Okechukwu  Azubuike        Nigeria    male
# 3  32171   Jeremiah       Azu  Great Britain    male
# 4  27116    Jeremie      Azou         France    male
#
#                                          profile_url  \
# 0  https://olympics-statistics.com/olympic-athlet...
# 1  https://olympics-statistics.com/olympic-athlet...
# 2  https://olympics-statistics.com/olympic-athlet...
# 3  https://olympics-statistics.com/olympic-athlet...
# 4  https://olympics-statistics.com/olympic-athlet...
#
#                                            medailles
# 0  {'nombre': 1, 'types': ['or'], 'sport': 'Baske...
# 1  {'nombre': 1, 'types': ['bronze'], 'sport': 'F...
# 2  {'nombre': 1, 'types': ['bronze'], 'sport': 'F...
# 3  {'nombre': 1, 'types': ['bronze'], 'sport': 'A...
# 4  {'nombre': 1, 'types': ['or'], 'sport': 'Rowing'}
# Colonnes: ['id', 'prenom', 'nom', 'pays', 'sexe', 'profile_url', 'medailles']
# ATTENTION: Codes pays non résolus: uz, sy, uy, ma, kp, tn, sm, lu, cm, jo, dz, lc, sa, qa, ae, ug, pr, tj
# Données nettoyées enregistrées au format JSON dans 'athletes_clean.json'
# Nombre d'athlètes enregistrés: 1216
#
# Aperçu du premier athlète au format JSON:
# {
#   "id": "25024",
#   "prenom": "Jennifer",
#   "nom": "Azzi",
#   "pays": "États-Unis",
#   "sexe": "female",
#   "profile_url": "https://olympics-statistics.com/olympic-athlete/Jennifer-Azzi/25024",
#   "or": 1,
#   "argent": 0,
#   "bronze": 0,
#   "sport": "Basketball",
#   "nom_complet": "Jennifer Azzi"
# }
#
# Données nettoyées sauvegardées dans athletesjsd
#
# Aperçu après nettoyage:
#       id     prenom       nom             pays    sexe  \
# 0  25024   Jennifer      Azzi       États-Unis  female
# 1  31553       Sera     Azuma            Japan  female
# 2  27117  Okechukwu  Azubuike          Nigeria    male
# 3  32171   Jeremiah       Azu  Grande-Bretagne    male
# 4  27116    Jeremie      Azou           France    male
#
#                                          profile_url  or  argent  bronze  \
# 0  https://olympics-statistics.com/olympic-athlet...   1       0       0
# 1  https://olympics-statistics.com/olympic-athlet...   0       0       1
# 2  https://olympics-statistics.com/olympic-athlet...   0       0       1
# 3  https://olympics-statistics.com/olympic-athlet...   0       0       1
# 4  https://olympics-statistics.com/olympic-athlet...   1       0       0
#
#         sport         nom_complet
# 0  Basketball       Jennifer Azzi
# 1     Fencing          Sera Azuma
# 2    Football  Okechukwu Azubuike
# 3   Athletics        Jeremiah Azu
# 4      Rowing        Jeremie Azou

# %%
# Out:
# Nombre d'athlètes trouvés: 1216
# Traitement de l'athlète 1/1216
# Erreur lors de l'exécution du script: 'pays_code'

# %%
#Script marche pareil que en haut

#ATHLETES

from bs4 import BeautifulSoup
import requests
import json
import re

pays_dict = {
    'afghanistan': 'af',
    'albania': 'al',
    'algeria': 'dz',         
    'argentina': 'ar',
    'armenia': 'am',
    'australia': 'au',
    'australia / new zealand (australasia)': 'au/nz',
    'austria': 'at',
    'austria / united states of amerika': 'at/us',
    'azerbaijan': 'az',
    'bahamas': 'bs',
    'bahrain': 'bh',
    'barbados': 'bb',
    'belarus': 'by',
    'belgium': 'be',
    'bermuda': 'bm',
    'bohemia': 'cz',
    'bohemia / great britain': 'cz/gb',
    'botswana': 'bw',
    'brazil': 'br',
    'bulgaria': 'bg',
    'burkina-faso': 'bf',
    'burundi': 'bi',
    'cameroon': 'cm',         
    'canada': 'ca',
    'cape verde': 'cv',
    'chile': 'cl',
    'china': 'cn',
    'chinese taipei': 'tw',
    'colombia': 'co',
    'commonwealth of independent states': 'cis',
    'costa rica': 'cr',
    'cote divoire': 'ci',
    'croatia': 'hr',
    'cuba': 'cu',
    'cyprus': 'cy',
    'czech republic': 'cz',
    'czechoslovakia': 'cs',
    'denmark': 'dk',
    'djibouti': 'dj',
    'dominican': 'dm',
    'dominican republic': 'do',
    'ecuador': 'ec',
    'egypt': 'eg',
    'eritrea': 'er',
    'estonia': 'ee',
    'ethiopia': 'et',
    'federal republic of germany': 'de',
    'fiji': 'fj',
    'finland': 'fi',
    'france': 'fr',
    'france / great britain': 'fr/gb',
    'france / great britain / ireland': 'fr/gb/ie',
    'gabon': 'ga',
    'georgia': 'ge',
    'german democratic republic': 'dd',
    'germany': 'de',
    'ghana': 'gh',
    'great britain': 'gb',
    'great britain / australia': 'gb/au',
    'great britain / france / united states of america': 'gb/fr/us',
    'great britain / ireland': 'gb/ie',
    'great britain / ireland / germany': 'gb/ie/de',
    'greece': 'gr',
    'greece / belgium': 'gr/be',
    'grenada': 'gd',
    'guatemala': 'gt',
    'guyana': 'gy',
    'haiti': 'ht',
    'hong kong': 'hk',
    'hungary': 'hu',
    'iceland': 'is',
    'independent olympic participants': 'iop',
    'india': 'in',
    'individual neutral athletes': 'ina',
    'individual olympic athletes': 'ioa',
    'indonesia': 'id',
    'iran': 'ir',
    'iraq': 'iq',
    'ireland': 'ie',
    'israel': 'il',
    'italy': 'it',
    'jamaica': 'jm',
    'japan': 'jp',
    'japan / korea': 'jp/kr',
    'jordan': 'jo',         
    'kazakhstan': 'kz',
    'kenya': 'ke',
    'kosovo': 'xk',
    'kuwait': 'kw',
    'kyrgyzstan': 'kg',
    'latvia': 'lv',
    'lebanon': 'lb',
    'liechtenstein': 'li',
    'lithuania': 'lt',
    'luxembourg': 'lu',       
    'luxembourg / france': 'lu/fr',
    'malaysia': 'my',
    'mauritius': 'mu',
    'mexico': 'mx',
    'moldova': 'md',
    'mongolia': 'mn',
    'montenegro': 'me',
    'morocco': 'ma',         
    'mozambique': 'mz',
    'namibia': 'na',
    'netherlands': 'nl',
    'netherlands / france': 'nl/fr',
    'netherlands antilles': 'an',
    'new zealand': 'nz',
    'niger': 'ne',
    'nigeria': 'ng',
    'north korea': 'kp',     
    'north-macedonia': 'mk',
    'norway': 'no',
    'pakistan': 'pk',
    'panama': 'pa',
    'paraguay': 'py',
    'peru': 'pe',
    'philippines': 'ph',
    'poland': 'pl',
    'portugal': 'pt',
    'puerto rico': 'pr',     
    'qatar': 'qa',        
    'refugee olympic team': 'rot',
    'romania': 'ro',
    'russia': 'ru',
    'russian olympic committee': 'roc',
    'saint lucia': 'lc',     
    'samoa': 'ws',
    'san marino': 'sm',   
    'saudi arabia': 'sa',     
    'senegal': 'sn',
    'serbia': 'rs',
    'serbia montenegro': 'cs',
    'singapore': 'sg',
    'slovakia': 'sk',
    'slovenia': 'si',
    'smyrna': 'tr',
    'south africa': 'za',
    'south korea': 'kr',
    'soviet union': 'su',
    'spain': 'es',
    'sri lanka': 'lk',
    'sudan': 'sd',
    'suriname': 'sr',
    'sweden': 'se',
    'sweden / denmark': 'se/dk',
    'switzerland': 'ch',
    'syria': 'sy',           
    'tajikistan': 'tj',      
    'tanzania': 'tz',
    'thailand': 'th',
    'thessalonika': 'gr',
    'togo': 'tg',
    'tonga': 'to',
    'trinidad & tobago': 'tt',
    'tunisia': 'tn',         
    'turkey': 'tr',
    'turkmenistan': 'tm',
    'uganda': 'ug',          
    'ukraine': 'ua',
    'united arab emirates': 'ae', 
    'united states of america': 'us',
    'united states of america / cuba': 'us/cu',
    'united states of america / france': 'us/fr',
    'united states of america / germany': 'us/de',
    'united states of america / great britain': 'us/gb',
    'united states of america / mexico': 'us/mx',
    'uruguay': 'uy',       
    'uzbekistan': 'uz',      
    'venezuela': 've',
    'vietnam': 'vn',
    'virgin islands': 'vi',
    'west indies federation': 'wif',
    'yugoslavia': 'yu',
    'zambia': 'zm',
    'zimbabwe': 'zw'
}

# Création d'un dictionnaire inversé pour recherche par code
codes_pays_dict = {v: k for k, v in pays_dict.items()}

def extract_basic_info(person, pays_dict):
    """Extrait les informations de base d'un élément HTML d'athlète"""
    # Extraire l'URL du profil et l'ID de l'athlète
    link = person.get('href')
    athlete_id = None
    if link:
        id_match = re.search(r'/olympic-athlete/[^/]+/(\d+)', link)
        if id_match:
            athlete_id = id_match.group(1)
    
    # Extraire le prénom et le nom
    prenom_div = person.select_one('div.vn')
    nom_div = person.select_one('div.n')
    prenom = prenom_div.get_text(strip=True) if prenom_div else ""
    nom = nom_div.get_text(strip=True) if nom_div else ""
    
    # Extraire le pays
    flag_img = person.select_one('img[src*="flagge"]')
    pays = flag_img.get('alt') if flag_img and flag_img.get('alt') else ""
    
    # Si le pays est vide, essayer d'extraire à partir du nom de fichier
    if not pays and flag_img and flag_img.get('src'):
        src = flag_img.get('src')
        pays_code = src.split('/')[-1].split('.')[0]
        # Remplacer le code pays par le nom complet s'il existe dans le dictionnaire inversé
        pays = codes_pays_dict.get(pays_code.lower(), pays_code)
    
    # Extraire le sexe
    sexe = ""
    if person.select_one('svg.female'):
        sexe = 'female'
    elif person.select_one('svg.male'):
        sexe = 'male'
    
    # Créer le dictionnaire de l'utilisateur
    user = {
        'id': athlete_id,
        'prenom': prenom,
        'nom': nom,
        'pays': pays,
        'sexe': sexe,
        'profile_url': f"https://olympics-statistics.com{link}" if link else "",
        'medailles': {
            'nombre': 0,
            'types': [],
            'sport': ""
        }
    }
    
    return user

def extract_medal_info(profile_url):
    """Extrait les informations de médailles depuis l'URL du profil d'un athlète"""
    try:
        response = requests.get(profile_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Initialisation
        nombre_medailles = 0
        types_medailles = []
        sport = ""
        
        # Trouver les divs de médailles
        medals = soup.select('.deck .medaille.visible')
        nombre_medailles = len(medals)
        
        for medal in medals:
            # Type de médaille (1: or, 2: argent, 3: bronze)
            medal_div = medal.select_one('.the-medal')
            if medal_div and medal_div.has_attr('data-medal'):
                code = medal_div['data-medal']
                if code == '1':
                    types_medailles.append("or")
                elif code == '2':
                    types_medailles.append("argent")
                elif code == '3':
                    types_medailles.append("bronze")
            
            # Sport
            sport_div = medal.select_one('.m-sport')
            if sport_div:
                sport = sport_div.text.strip()
        
        return {
            'nombre': nombre_medailles,
            'types': types_medailles,
            'sport': sport
        }
    except Exception as e:
        print(f"Erreur lors de l'extraction des médailles pour {profile_url}: {str(e)}")
        return {
            'nombre': 0,
            'types': [],
            'sport': ""
        }

def main():
    # URL principale pour la liste des athlètes
    main_url = "https://olympics-statistics.com/olympic-athletes"
    
    try:
        # Récupérer la page principale
        response = requests.get(main_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extraire les cartes d'athlètes - cette fois nous allons directement chercher les liens
        athletes_links = soup.select('a.card.athlet.visible')
        
        print(f"Nombre d'athlètes trouvés: {len(athletes_links)}")
        
        users = []
        for i, athlete_link in enumerate(athletes_links):
            print(f"Traitement de l'athlète {i+1}/{len(athletes_links)}")
            
            # Extraire les informations de base avec le dictionnaire des pays
            user = extract_basic_info(athlete_link, pays_dict)
            
            if user['profile_url']:
                # Obtenir les informations de médailles
                medals_info = extract_medal_info(user['profile_url'])
                user['medailles'] = medals_info
                
                users.append(user)
                print(f"  - {user['prenom']} {user['nom']} (ID: {user['id']}) de {user['pays']} ajouté avec succès")
            else:
                print(f"  - Impossible de traiter l'athlète, URL du profil manquante")
        
        # Sauvegarder dans un fichier JSON
        output_file = "athletes.json"
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(users, f, ensure_ascii=False, indent=4)
        
        print(f"Informations sauvegardées pour {len(users)} athlètes dans {output_file}")
        
#         # Aperçu
#         from pprint import pprint
#         print("\nAperçu du premier athlète:")
#         if users:
#             pprint(users[0])
    
    except Exception as e:
        print(f"Erreur lors de l'exécution du script: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Nombre d'athlètes trouvés: 1216
# Traitement de l'athlète 1/1216
#   - Jennifer Azzi (ID: 25024) de united states of america ajouté avec succès
# Traitement de l'athlète 2/1216
#   - Sera Azuma (ID: 31553) de japan ajouté avec succès
# Traitement de l'athlète 3/1216
#   - Okechukwu Azubuike (ID: 27117) de nigeria ajouté avec succès
# Traitement de l'athlète 4/1216
#   - Jeremiah Azu (ID: 32171) de great britain ajouté avec succès
# Traitement de l'athlète 5/1216
#   - Jeremie Azou (ID: 27116) de france ajouté avec succès
# Traitement de l'athlète 6/1216
#   - Sandra Azon (ID: 25023) de spain ajouté avec succès
# Traitement de l'athlète 7/1216
#   - Karina Aznavourian (ID: 25022) de 1613584988 ajouté avec succès
# Traitement de l'athlète 8/1216
#   - Minneula Azizov (ID: 25021) de urs ajouté avec succès
# Traitement de l'athlète 9/1216
#   - Abdul Wahid Aziz (ID: 25019) de iraq ajouté avec succès
# Traitement de l'athlète 10/1216
#   - Salihu Aziz (ID: 25020) de 1613623257 ajouté avec succès
# Traitement de l'athlète 11/1216
#   - Tony Azevedo (ID: 25018) de united states of america ajouté avec succès
# Traitement de l'athlète 12/1216
#   - Filiberto Azcuy (ID: 24891) de cuba ajouté avec succès
# Traitement de l'athlète 13/1216
#   - Isaac Azcuy (ID: 25017) de cuba ajouté avec succès
# Traitement de l'athlète 14/1216
#   - Albert Azaryan (ID: 25015) de urs ajouté avec succès
# Traitement de l'athlète 15/1216
#   - Per Olof Arvidsson (ID: 24872) de sweden ajouté avec succès
# Traitement de l'athlète 201/1216
#   - Migran Arutyunyan (ID: 27106) de armenia ajouté avec succès
# Traitement de l'athlète 202/1216
#   - Zorana Arunovic (ID: 31370) de serbia ajouté avec succès
# Traitement de l'athlète 203/1216
#   - Vladimir Artyomov (ID: 24870) de urs ajouté avec succès
# Traitement de l'athlète 204/1216
#   - Sedat Artuç (ID: 24869) de turkey ajouté avec succès
# Traitement de l'athlète 205/1216
#   - Juan Artola (ID: 24868) de spain ajouté avec succès
# Traitement de l'athlète 206/1216
#   - Karriss Artingstall (ID: 29694) de great britain ajouté avec succès
# Traitement de l'athlète 207/1216
#   - Edouard Artigas (ID: 24867) de france ajouté avec succès
# Traitement de l'athlète 208/1216
#   - Henri Arthus (ID: 24866) de france ajouté avec succès
# Traitement de l'athlète 209/1216
#   - John Arthur (ID: 24865) de south africa ajouté avec succès
# Traitement de l'athlète 210/1216
#   - Olga Arteshina (ID: 24864) de 1613584988 ajouté avec succès
# Traitement de l'athlète 211/1216
#   - Alexander Artemev (ID: 24863) de united states of america ajouté avec succès
# Traitement de l'athlète 212/1216
#   - Bakhtiyar Artayev (ID: 24862) de kazakhstan ajouté avec succès
# Traitement de l'athlète 213/1216
#   - Yevgeniya Artamonova (ID: 24861) de 1613584988 ajouté avec succès
# Traitement de l'athlète 214/1216
#   - Michail Artamonov (ID: 29014) de 1521398891 ajouté avec succès
# Traitement de l'athlète 215/1216
#   - Mariafe Artacho del Solar (ID: 30092) de australia ajouté avec succès
# Traitement de l'athlète 216/1216
#   - Abaz Arslanagic (ID: 24860) de 1613623257 ajouté avec succès
# Traitement de l'athlète 217/1216
#   - Samantha Arsenault (ID: 24859) de united states of america ajouté avec succès
# Traitement de l'athlète 218/1216
#   - Israil Arsamakov (ID: 24858) de urs ajouté avec succès
# Traitement de l'athlète 219/1216
#   - Francisco Arrue (ID: 24857) de chile ajouté avec succès
# Traitement de l'athlète 220/1216
#   - Ines Arrondo (ID: 24856) de argentina ajouté avec succès
# Traitement de l'athlète 221/1216
#   - Christine Arron (ID: 24855) de france ajouté avec succès
# Traitement de l'athlète 222/1216
# Erreur lors de l'extraction des médailles pour https://olympics-statistics.com/olympic-athlete/Rolando-Arrojo/24854: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   - Rolando Arrojo (ID: 24854) de cuba ajouté avec succès
# Traitement de l'athlète 223/1216
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [27], in <cell line: 335>()
#     333         print(f"Erreur lors de l'exécution du script: {str(e)}")
#     335 if __name__ == "__main__":
# --> 336     main()
#
# Input In [27], in main()
#     307 user = extract_basic_info(athlete_link, pays_dict)
#     309 if user['profile_url']:
#     310     # Obtenir les informations de médailles
# --> 311     medals_info = extract_medal_info(user['profile_url'])
#     312     user['medailles'] = medals_info
#     314     users.append(user)
#
# Input In [27], in extract_medal_info(profile_url)
#     244 """Extrait les informations de médailles depuis l'URL du profil d'un athlète"""
#     245 try:
# --> 246     response = requests.get(profile_url)
#     247     soup = BeautifulSoup(response.text, 'html.parser')
#     249     # Initialisation
#
# File ~\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1038 # Force connect early to allow us to validate the connection.
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#    1043     warnings.warn(
#    1044         (
#    1045             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1050         InsecureRequestWarning,
#    1051     )
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~\anaconda3\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~\anaconda3\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~\anaconda3\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:
