# %%
from bs4 import BeautifulSoup
import requests
import json
import re
import time

def extract_medals_by_nation(sport_url, pays_dict):

    try:

        response = requests.get(sport_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        

        sport_name = "Unknown Sport"
        sport_title = soup.select_one('h1')
        if sport_title:
            sport_name = sport_title.text.strip()
            sport_name = sport_name.replace("Olympic Medals in Sport ", "")
        else:

            match = re.search(r'/olympic-sport/([^/]+)', sport_url)
            if match:
                sport_name = match.group(1).replace('-', ' ')
        
        # Trouver les cartes de nations dans la section TOP NATIONS
        nations = []
        
        # Chercher directement les cartes de nations qui sont visibles
        nation_cards = soup.select('div.cards div.card.nation.visible')
        
        if not nation_cards:
            # Si pas trouvé avec cette méthode, essayer une autre
            nation_cards = soup.select('div.deck div.card.nation.visible')
        
        print(f"Nombre de nations trouvées pour {sport_name}: {len(nation_cards)}")
        
        for nation_card in nation_cards:
            # Extraire le nom du pays
            nation_name = ""
            name_elem = nation_card.select_one('div.bez')
            if name_elem:
                nation_name = name_elem.text.strip()
            
            # Si pas de nom, passer à la carte suivante
            if not nation_name:
                continue
            
            # Extraire le nombre total de médailles
            total_medals = 0
            medals_elem = nation_card.select_one('div.mal-ges')
            if medals_elem:
                medals_text = medals_elem.text.strip()
                medals_match = re.search(r'(\d+)', medals_text)
                if medals_match:
                    total_medals = int(medals_match.group(1))
            
            # Extraire les médailles d'or, d'argent et de bronze
            gold = 0
            silver = 0
            bronze = 0
            
            # Récupérer les médailles spécifiques
            medal_elems = nation_card.select('div.medals div[data-c]')
            for medal_elem in medal_elems:
                medal_count_elem = medal_elem.select_one('span.mal')
                if medal_count_elem:
                    medal_count = medal_count_elem.text.strip()
                    medal_count = int(medal_count) if medal_count.isdigit() else 0
                    
                    medal_type_elem = medal_elem.select_one('div.the-medal')
                    if medal_type_elem:
                        medal_type = medal_type_elem.get('data-medal')
                        if medal_type == '1':
                            gold = medal_count
                        elif medal_type == '2':
                            silver = medal_count
                        elif medal_type == '3':
                            bronze = medal_count
            
            # Créer l'objet nation
            nation = {
                "nom": nation_name,
                "medailles": {
                    "total": total_medals,
                    "or": gold,
                    "argent": silver,
                    "bronze": bronze
                }
            }
            
            # Ajouter le code pays si disponible
            for code, name in pays_dict.items():
                if name.lower() == nation_name.lower():
                    nation["code_pays"] = code
                    break
            
            nations.append(nation)
        
        return {
            "sport": sport_name,
            "nations": nations
        }
        
    except Exception as e:
        print(f"Erreur lors de l'extraction des médailles pour {sport_url}: {str(e)}")
        return {"sport": sport_url, "nations": [], "error": str(e)}

def main():
    # Dictionnaire des codes pays
    pays_dict = {
        'us': 'United States',
        'fr': 'France',
        'fi': 'Finland',
        'de': 'Germany',
        'it': 'Italy',
        'gb': 'Great Britain',
        'uk': 'United Kingdom',
        'ca': 'Canada',
        'au': 'Australia',
        'es': 'Spain',
        'se': 'Sweden',
        'ch': 'Switzerland',
        'no': 'Norway',
        'nl': 'Netherlands',
        'br': 'Brazil',
        'cn': 'China',
        'jp': 'Japan',
        'kr': 'South Korea',
        'ru': 'Russia',
        'ua': 'Ukraine',
        'pl': 'Poland',
        'ro': 'Romania',
        'cz': 'Czech Republic',
        'at': 'Austria',
        'hu': 'Hungary',
        'gr': 'Greece',
        'dk': 'Denmark',
        'be': 'Belgium',
        'mx': 'Mexico',
        'ar': 'Argentina',
        'za': 'South Africa',
        'nz': 'New Zealand',
        'tr': 'Turkey',
        'in': 'India',
        'pt': 'Portugal',
        'il': 'Israel',
        'ie': 'Ireland',
        'hr': 'Croatia',
        'bg': 'Bulgaria',
        'sk': 'Slovakia',
        'si': 'Slovenia',
        'th': 'Thailand',
        'sg': 'Singapore',
        'my': 'Malaysia',
        'id': 'Indonesia',
        'vn': 'Vietnam',
        'ph': 'Philippines',
        'ir': 'Iran',
        'eg': 'Egypt',
        'ke': 'Kenya',
        'et': 'Ethiopia',
        'ng': 'Nigeria',
        'co': 'Colombia',
        'cl': 'Chile',
        'pe': 'Peru',
        've': 'Venezuela',
        'lt': 'Lithuania',
        'iq': 'Iraq',
        'cu': 'Cuba',
        'pk': 'Pakistan',
        'by': 'Belarus',
        'ht': 'Haiti',
        'is': 'Iceland',
        'kz': 'Kazakhstan',
        'az': 'Azerbaijan',
        'jm': 'Jamaica',
        'do': 'Dominican Republic',
        'gh': 'Ghana',
        'rs': 'Serbia',
        'tt': 'Trinidad and Tobago',
        'lv': 'Latvia',
        'gy': 'Guyana',
        'am': 'Armenia',
        'bw': 'Botswana',
        'urs': 'Soviet Union'
    }
    
    # URL de base pour les sports olympiques
    main_url = "https://olympics-statistics.com/olympic-sports"
    
    try:
        # Récupérer la page principale des sports
        response = requests.get(main_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extraire les liens vers les sports
        sport_links = soup.select('a.card.sport.visible')
        
        print(f"Nombre de sports trouvés: {len(sport_links)}")
        
        sports_data = []
        for i, sport_link in enumerate(sport_links):
            href = sport_link.get('href', '')
            if not href:
                continue
                
            sport_url = f"https://olympics-statistics.com{href}"
            sport_name = sport_link.select_one('div.bez').text.strip() if sport_link.select_one('div.bez') else "Unknown Sport"
            
            print(f"Traitement du sport {i+1}/{len(sport_links)}: {sport_name}")
            
            # Extraire les médailles par nation pour ce sport
            sport_data = extract_medals_by_nation(sport_url, pays_dict)
            sports_data.append(sport_data)
            
            # Afficher un résumé des données extraites
            nation_count = len(sport_data.get('nations', []))
            print(f"  - {nation_count} nations trouvées dans TOP NATIONS pour {sport_name}")
            
            # Liste des trois premières nations pour vérification
            if nation_count > 0:
                top_nations = [nation['nom'] for nation in sport_data.get('nations', [])[:3]]
                print(f"  - Top nations: {', '.join(top_nations)}")
            
            # Ajout d'un délai pour éviter de surcharger le serveur
            time.sleep(1)
        
        # Sauvegarder dans un fichier JSON
        output_file = "sports_medals.json"
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(sports_data, f, ensure_ascii=False, indent=4)
        
        print(f"Informations sauvegardées pour {len(sports_data)} sports dans {output_file}")
        
    except Exception as e:
        print(f"Erreur lors de l'exécution du script: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Nombre de sports trouvés: 68
# Traitement du sport 1/68: Aeronautics
# Nombre de nations trouvées pour Aeronautics: 1
#   - 1 nations trouvées dans TOP NATIONS pour Aeronautics
#   - Top nations: Switzerland
# 1
# Traitement du sport 2/68: Alpine Skiing
# Nombre de nations trouvées pour Alpine Skiing: 8
#   - 8 nations trouvées dans TOP NATIONS pour Alpine Skiing
#   - Top nations: Austria
# 128, Switzerland
# 75, United States of America
# 48
# Traitement du sport 3/68: Alpinism
# Nombre de nations trouvées pour Alpinism: 3
#   - 3 nations trouvées dans TOP NATIONS pour Alpinism
#   - Top nations: Germany
# 1, Great Britain / Australia
# 1, Switzerland
# 1
# Traitement du sport 4/68: Archery
# Nombre de nations trouvées pour Archery: 8
#   - 8 nations trouvées dans TOP NATIONS pour Archery
#   - Top nations: South Korea
# 50, United States of America
# 36, Belgium
# 21
# Traitement du sport 5/68: Athletics
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 239>()
#     237         print(f"Erreur lors de l'exécution du script: {str(e)}")
#     239 if __name__ == "__main__":
# --> 240     main()
#
# Input In [6], in main()
#     211 print(f"Traitement du sport {i+1}/{len(sport_links)}: {sport_name}")
#     213 # Extraire les médailles par nation pour ce sport
# --> 214 sport_data = extract_medals_by_nation(sport_url, pays_dict)
#     215 sports_data.append(sport_data)
#     217 # Afficher un résumé des données extraites
#
# Input In [6], in extract_medals_by_nation(sport_url, pays_dict)
#       9 try:
#      10     # Accéder à la page du sport
#      11     response = requests.get(sport_url)
# ---> 12     soup = BeautifulSoup(response.text, 'html.parser')
#      14     # Extraire le nom du sport
#      15     sport_name = "Unknown Sport"
#
# File ~\anaconda3\lib\site-packages\bs4\__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File ~\anaconda3\lib\site-packages\bs4\__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File ~\anaconda3\lib\site-packages\bs4\builder\_htmlparser.py:399, in HTMLParserTreeBuilder.feed(self, markup)
#     397 parser.soup = self.soup
#     398 try:
# --> 399     parser.feed(markup)
#     400     parser.close()
#     401 except HTMLParseError as e:
#
# File ~\anaconda3\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~\anaconda3\lib\html\parser.py:170, in HTMLParser.goahead(self, end)
#     168 if startswith('<', i):
#     169     if starttagopen.match(rawdata, i): # < + letter
# --> 170         k = self.parse_starttag(i)
#     171     elif startswith("</", i):
#     172         k = self.parse_endtag(i)
#
# File ~\anaconda3\lib\html\parser.py:344, in HTMLParser.parse_starttag(self, i)
#     342     self.handle_startendtag(tag, attrs)
#     343 else:
# --> 344     self.handle_starttag(tag, attrs)
#     345     if tag in self.CDATA_CONTENT_ELEMENTS:
#     346         self.set_cdata_mode(tag)
#
# File ~\anaconda3\lib\site-packages\bs4\builder\_htmlparser.py:154, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     152 #print("START", name)
#     153 sourceline, sourcepos = self.getpos()
# --> 154 tag = self.soup.handle_starttag(
#     155     name, None, None, attr_dict, sourceline=sourceline,
#     156     sourcepos=sourcepos
#     157 )
#     158 if tag and tag.is_empty_element and handle_empty_element:
#     159     # Unlike other parsers, html.parser doesn't send separate end tag
#     160     # events for empty-element tags. (It's handled in
#    (...)
#     166     # don't want handle_endtag() to cross off any previous end
#     167     # events for tags of this name.
#     168     self.handle_endtag(name, check_already_closed=False)
#
# File ~\anaconda3\lib\site-packages\bs4\__init__.py:721, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     716 if (self.parse_only and len(self.tagStack) <= 1
#     717     and (self.parse_only.text
#     718          or not self.parse_only.search_tag(name, attrs))):
#     719     return None
# --> 721 tag = self.element_classes.get(Tag, Tag)(
#     722     self, self.builder, name, namespace, nsprefix, attrs,
#     723     self.currentTag, self._most_recent_element,
#     724     sourceline=sourceline, sourcepos=sourcepos,
#     725     namespaces=namespaces
#     726 )
#     727 if tag is None:
#     728     return tag
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:1231, in Tag.__init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml, sourceline, sourcepos, can_be_empty_element, cdata_list_attributes, preserve_whitespace_tags, interesting_string_types, namespaces)
#    1229 if name is None:
#    1230     raise ValueError("No value provided for new tag's name.")
# -> 1231 self.name = name
#    1232 self.namespace = namespace
#    1233 self._namespaces = namespaces or {}
#
# KeyboardInterrupt:

# %%
import json
import pandas as pd
import re

# Chargement des données
try:
    with open('sports_medals.json', 'r', encoding='utf-8') as f:
        sports_data = json.load(f)
    print(f"Données chargées : {len(sports_data)} sports trouvés")
# except FileNotFoundError:
#     print("Fichier sports_medals.json introuvable. Exécutez d'abord le script principal.")
#     sports_data = []

# Dictionnaire simplifié pour les codes pays
pays_dict = {
    'afghanistan': 'af', 'albania': 'al', 'algeria': 'dz', 'argentina': 'ar',
    'armenia': 'am', 'australia': 'au', 'austria': 'at', 'azerbaijan': 'az',
    'bahamas': 'bs', 'belarus': 'by', 'belgium': 'be', 'brazil': 'br',
    'bulgaria': 'bg', 'cameroon': 'cm', 'canada': 'ca', 'chile': 'cl',
    'china': 'cn', 'chinese taipei': 'tw', 'colombia': 'co', 'croatia': 'hr',
    'cuba': 'cu', 'czech republic': 'cz', 'denmark': 'dk', 'egypt': 'eg',
    'estonia': 'ee', 'ethiopia': 'et', 'finland': 'fi', 'france': 'fr',
    'georgia': 'ge', 'germany': 'de', 'great britain': 'gb', 'greece': 'gr',
    'hungary': 'hu', 'india': 'in', 'indonesia': 'id', 'iran': 'ir',
    'ireland': 'ie', 'israel': 'il', 'italy': 'it', 'jamaica': 'jm',
    'japan': 'jp', 'kazakhstan': 'kz', 'kenya': 'ke', 'latvia': 'lv',
    'lithuania': 'lt', 'malaysia': 'my', 'mexico': 'mx', 'mongolia': 'mn',
    'morocco': 'ma', 'netherlands': 'nl', 'new zealand': 'nz', 'nigeria': 'ng',
    'north korea': 'kp', 'norway': 'no', 'pakistan': 'pk', 'poland': 'pl',
    'portugal': 'pt', 'romania': 'ro', 'russia': 'ru', 'serbia': 'rs',
    'slovakia': 'sk', 'slovenia': 'si', 'south africa': 'za', 'south korea': 'kr',
    'soviet union': 'su', 'spain': 'es', 'sweden': 'se', 'switzerland': 'ch',
    'thailand': 'th', 'turkey': 'tr', 'ukraine': 'ua', 'united states': 'us', 
    'united states of america': 'us', 'uzbekistan': 'uz', 'yugoslavia': 'yu'
}

def nettoyer_data_conserver_tous():
    """
    Cette fonction conserve EXACTEMENT tous les sports originaux
    et modifie uniquement le format interne des données.
    """
    # Liste pour stocker les sports nettoyés
    sports_propres = []
    
    # Parcourir exactement tous les sports originaux
    for index, sport_orig in enumerate(sports_data):
        # Extraire le nom du sport
        sport_name = sport_orig.get('sport', f"Sport inconnu {index}")
        
        # Nettoyer légèrement le nom si nécessaire
        if sport_name.startswith("Olympic Medals in Sport "):
            sport_name = sport_name[24:].strip()
            
        # Liste pour stocker les nations nettoyées
        nations_propres = []
        
        # Traiter les nations si elles existent
        nations_orig = sport_orig.get('nations', [])
        for nation in nations_orig:
            # Extraire le nom de la nation
            nation_name_raw = nation.get('nom', '').strip()
            
            # Traiter le format potentiel "Nombre, Pays"
            match = re.match(r'^(\d+),\s*(.+)$', nation_name_raw)
            if match:
                medal_count = int(match.group(1))
                nation_name = match.group(2).strip().title()
            else:
                nation_name = nation_name_raw.title() if nation_name_raw else ""
                medal_count = 0
            
            # Si pas de nom valide, passer à la suite
            if not nation_name:
                continue
                
            # Extraire les médailles
            medailles = nation.get('medailles', {})
            or_medals = medailles.get('or', 0)
            argent_medals = medailles.get('argent', 0)
            bronze_medals = medailles.get('bronze', 0)
            total_medals = medailles.get('total', 0)
            
            # Si le total vient du format "Nombre, Pays"
            if match and total_medals == 0:
                total_medals = medal_count
                
            # Si toujours pas de total mais des médailles par type
            if total_medals == 0 and (or_medals > 0 or argent_medals > 0 or bronze_medals > 0):
                total_medals = or_medals + argent_medals + bronze_medals
            
            # Trouver le code pays
            pays_code = ""
            nom_lower = nation_name.lower()
            if nom_lower in pays_dict:
                pays_code = pays_dict[nom_lower]
            elif 'united states' in nom_lower:
                pays_code = 'us'
            elif 'great britain' in nom_lower:
                pays_code = 'gb'
            
            # Créer la nation propre
            nation_propre = {
                'nom': nation_name,
                'pays_code': pays_code,
                'or': or_medals,
                'argent': argent_medals,
                'bronze': bronze_medals,
                'total': total_medals
            }
            
            nations_propres.append(nation_propre)
        
        # Trier les nations par médailles
        nations_propres = sorted(nations_propres, key=lambda x: x['total'], reverse=True)
        
        # Créer le sport propre
        sport_propre = {
            'nom': sport_name,
            'nombre_nations': len(nations_propres),
            'nations': nations_propres
        }
        
        sports_propres.append(sport_propre)
    
    # Afficher les statistiques
    print(f"Nombre de sports originaux: {len(sports_data)}")
    print(f"Nombre de sports après nettoyage: {len(sports_propres)}")
    
    # Lister les sports pour vérification
    print("\nListe complète des sports traités:")
    for i, sport in enumerate(sports_propres):
        print(f"{i+1}. {sport['nom']} - {sport['nombre_nations']} nations")
    
    # Enregistrer le fichier JSON
    with open('sports_medals_clean.json', 'w', encoding='utf-8') as f:
        json.dump(sports_propres, f, ensure_ascii=False, indent=4)
    
    print(f"\nFichier 'sports_medals_clean.json' créé avec {len(sports_propres)} sports.")
    
    # Vérification finale du fichier JSON
#     try:
#         with open('sports_medals_clean.json', 'r', encoding='utf-8') as f:
#             verify = json.load(f)
#         print(f"Vérification: Le fichier contient bien {len(verify)} sports.")
#     except Exception as e:
#         print(f"Erreur lors de la vérification: {str(e)}")
    
    return sports_propres

# Exécuter le nettoyage qui préserve tous les sports originaux
sports_clean = nettoyer_data_conserver_tous()
# Out:
# Données chargées : 68 sports trouvés
# Nombre de sports originaux: 68
# Nombre de sports après nettoyage: 68
#
# Liste complète des sports traités:
# 1. Aeronautics - 1 nations
# 2. Alpine Skiing - 8 nations
# 3. Alpinism - 3 nations
# 4. Archery - 8 nations
# 5. Athletics - 8 nations
# 6. Badminton - 8 nations
# 7. Baseball - 7 nations
# 8. Basketball - 8 nations
# 9. Beachvolleyball - 8 nations
# 10. Biathlon - 8 nations
# 11. Bobsledding - 8 nations
# 12. Boxing - 8 nations
# 13. Breaking - 6 nations
# 14. Canoe & Kayaking - 8 nations
# 15. Cricket - 2 nations
# 16. Crocket - 1 nations
# 17. Cross-Country Skiing - 8 nations
# 18. Curling - 8 nations
# 19. Cycling - 8 nations
# 20. Diving - 8 nations
# 21. Equestrian - 8 nations
# 22. Fencing - 8 nations
# 23. Figure Skating - 8 nations
# 24. Football - 8 nations
# 25. Freestyle Skiing - 8 nations
# 26. Golf - 8 nations
# 27. Gymnastics - 8 nations
# 28. Handball - 8 nations
# 29. Hockey - 8 nations
# 30. Ice Hockey - 8 nations
# 31. Jeu de Paume - 2 nations
# 32. Judo - 8 nations
# 33. Karate - 8 nations
# 34. Lacrosse - 3 nations
# 35. Luge - 8 nations
# 36. Modern Pentathlon - 8 nations
# 37. Motorboating - 2 nations
# 38. Nordic Combined - 8 nations
# 39. Pelota - 1 nations
# 40. Polo - 8 nations
# 41. Rackets - 1 nations
# 42. Rhythmic Gymnastics - 8 nations
# 43. Roque - 1 nations
# 44. Rowing - 8 nations
# 45. Rugby - 8 nations
# 46. Sailing - 8 nations
# 47. Shooting - 8 nations
# 48. Short Track - 8 nations
# 49. Skateboarding - 5 nations
# 50. Skeleton - 8 nations
# 51. Ski Jumping - 8 nations
# 52. Snowboard - 8 nations
# 53. Softball - 5 nations
# 54. Speed Skating - 8 nations
# 55. Sport climbing - 8 nations
# 56. Surfing - 6 nations
# 57. Swimming - 8 nations
# 58. Synchronized Swimming - 8 nations
# 59. Table Tennis - 8 nations
# 60. Taekwondo - 8 nations
# 61. Tennis - 8 nations
# 62. Trampolining - 8 nations
# 63. Triathlon - 8 nations
# 64. Tug of war - 8 nations
# 65. Volleyball - 8 nations
# 66. Water Polo - 8 nations
# 67. Weightlifting - 8 nations
# 68. Wrestling - 8 nations
#
# Fichier 'sports_medals_clean.json' créé avec 68 sports.
# Vérification: Le fichier contient bien 68 sports.

# %%
from bs4 import BeautifulSoup
import requests
import json
import re
import time

def extract_medals_by_nation(sport_url, pays_dict):
    try:
        response = requests.get(sport_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        sport_name = "Unknown Sport"
        sport_title = soup.select_one('h1')
        if sport_title:
            sport_name = sport_title.text.strip().replace("Olympic Medals in Sport ", "")
        else:
            match = re.search(r'/olympic-sport/([^/]+)', sport_url)
            if match:
                sport_name = match.group(1).replace('-', ' ')
        
        nation_cards = soup.select('div.cards div.card.nation.visible') or soup.select('div.deck div.card.nation.visible')
        print(f"Nombre de nations trouvées pour {sport_name}: {len(nation_cards)}")
        
        nations = []
        for nation_card in nation_cards:
            name_elem = nation_card.select_one('div.bez')
            if not name_elem:
                continue
                
            nation_name = name_elem.text.strip()
            
            medals_elem = nation_card.select_one('div.mal-ges')
            total_medals = 0
            if medals_elem:
                medals_match = re.search(r'(\d+)', medals_elem.text.strip())
                if medals_match:
                    total_medals = int(medals_match.group(1))
            
            medal_counts = {'or': 0, 'argent': 0, 'bronze': 0}
            medal_type_map = {'1': 'or', '2': 'argent', '3': 'bronze'}
            
            for medal_elem in nation_card.select('div.medals div[data-c]'):
                medal_count_elem = medal_elem.select_one('span.mal')
                if not medal_count_elem:
                    continue
                
                medal_count = medal_count_elem.text.strip()
                if not medal_count.isdigit():
                    continue
                    
                medal_type_elem = medal_elem.select_one('div.the-medal')
                if medal_type_elem:
                    medal_type = medal_type_elem.get('data-medal')
                    if medal_type in medal_type_map:
                        medal_counts[medal_type_map[medal_type]] = int(medal_count)
            
            nation = {
                "nom": nation_name,
                "medailles": {
                    "total": total_medals,
                    **medal_counts
                }
            }
            
            nation_name_lower = nation_name.lower()
            for code, name in pays_dict.items():
                if name.lower() == nation_name_lower:
                    nation["code_pays"] = code
                    break
            
            nations.append(nation)
        
        return {"sport": sport_name, "nations": nations}
        
    except Exception as e:
        print(f"Erreur pour {sport_url}: {str(e)}")
        return {"sport": sport_url, "nations": [], "error": str(e)}

def main():
    pays_dict = {
        'us': 'United States', 'fr': 'France', 'fi': 'Finland', 'de': 'Germany',
        'it': 'Italy', 'gb': 'Great Britain', 'uk': 'United Kingdom', 'ca': 'Canada',
        # Ajoutez tous les autres pays ici
        'urs': 'Soviet Union'
    }
    
    try:
        response = requests.get("https://olympics-statistics.com/olympic-sports")
        soup = BeautifulSoup(response.text, 'html.parser')
        sport_links = soup.select('a.card.sport.visible')
        
        print(f"Nombre de sports trouvés: {len(sport_links)}")
        
        sports_data = []
        for i, sport_link in enumerate(sport_links):
            href = sport_link.get('href')
            if not href:
                continue
                
            sport_url = f"https://olympics-statistics.com{href}"
            sport_name = sport_link.select_one('div.bez').text.strip() if sport_link.select_one('div.bez') else "Unknown Sport"
            
            print(f"Traitement du sport {i+1}/{len(sport_links)}: {sport_name}")
            
            sport_data = extract_medals_by_nation(sport_url, pays_dict)
            sports_data.append(sport_data)
            
            nations = sport_data.get('nations', [])
            print(f"  - {len(nations)} nations trouvées pour {sport_name}")
            
            if nations:
                top_nations = [nation['nom'] for nation in nations[:3]]
                print(f"  - Top nations: {', '.join(top_nations)}")
            
            time.sleep(0.5)
        
        with open("sports_medals.json", 'w', encoding='utf-8') as f:
            json.dump(sports_data, f, ensure_ascii=False, indent=4)
        
        print(f"Informations sauvegardées pour {len(sports_data)} sports")
        
    except Exception as e:
        print(f"Erreur d'exécution: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Nombre de sports trouvés: 68
# Traitement du sport 1/68: Aeronautics
# Nombre de nations trouvées pour Aeronautics: 1
#   - 1 nations trouvées pour Aeronautics
#   - Top nations: Switzerland
# 1
# Traitement du sport 2/68: Alpine Skiing
# Nombre de nations trouvées pour Alpine Skiing: 8
#   - 8 nations trouvées pour Alpine Skiing
#   - Top nations: Austria
# 128, Switzerland
# 75, United States of America
# 48
# Traitement du sport 3/68: Alpinism
# Nombre de nations trouvées pour Alpinism: 3
#   - 3 nations trouvées pour Alpinism
#   - Top nations: Germany
# 1, Great Britain / Australia
# 1, Switzerland
# 1
# Traitement du sport 4/68: Archery
# Nombre de nations trouvées pour Archery: 8
#   - 8 nations trouvées pour Archery
#   - Top nations: South Korea
# 50, United States of America
# 36, Belgium
# 21
# Traitement du sport 5/68: Athletics
# Nombre de nations trouvées pour Athletics: 8
#   - 8 nations trouvées pour Athletics
#   - Top nations: United States of America
# 884, Russia
# 273, Germany
# 271
# Traitement du sport 6/68: Badminton
# Nombre de nations trouvées pour Badminton: 8
#   - 8 nations trouvées pour Badminton
#   - Top nations: China
# 52, Indonesia
# 22, South Korea
# 22
# Traitement du sport 7/68: Baseball
# Nombre de nations trouvées pour Baseball: 7
#   - 7 nations trouvées pour Baseball
#   - Top nations: Cuba
# 5, Japan
# 4, United States of America
# 4
# Traitement du sport 8/68: Basketball
# Nombre de nations trouvées pour Basketball: 8
#   - 8 nations trouvées pour Basketball
#   - Top nations: United States of America
# 34, Russia
# 16, Yugoslavia
# 8
# Traitement du sport 9/68: Beachvolleyball
# Nombre de nations trouvées pour Beachvolleyball: 8
#   - 8 nations trouvées pour Beachvolleyball
#   - Top nations: United States of America
# 11, Brazil
# 14, Germany
# 4
# Traitement du sport 10/68: Biathlon
# Nombre de nations trouvées pour Biathlon: 8
#   - 8 nations trouvées pour Biathlon
#   - Top nations: Germany
# 70, Norway
# 55, Russia
# 47
# Traitement du sport 11/68: Bobsledding
# Nombre de nations trouvées pour Bobsledding: 8
#   - 8 nations trouvées pour Bobsledding
#   - Top nations: Germany
# 51, Switzerland
# 31, United States of America
# 28
# Traitement du sport 12/68: Boxing
# Nombre de nations trouvées pour Boxing: 8
#   - 8 nations trouvées pour Boxing
#   - Top nations: United States of America
# 118, Cuba
# 80, Russia
# 83
# Traitement du sport 13/68: Breaking
# Nombre de nations trouvées pour Breaking: 6
#   - 6 nations trouvées pour Breaking
#   - Top nations: Canada
# 1, Japan
# 1, France
# 1
# Traitement du sport 14/68: Canoe & Kayaking
# Nombre de nations trouvées pour Canoe & Kayaking: 8
#   - 8 nations trouvées pour Canoe & Kayaking
#   - Top nations: Germany
# 135, Russia
# 66, Hungary
# 93
# Traitement du sport 15/68: Cricket
# Nombre de nations trouvées pour Cricket: 2
#   - 2 nations trouvées pour Cricket
#   - Top nations: Great Britain
# 1, France
# 1
# Traitement du sport 16/68: Crocket
# Nombre de nations trouvées pour Crocket: 1
#   - 1 nations trouvées pour Crocket
#   - Top nations: France
# 7
# Traitement du sport 17/68: Cross-Country Skiing
# Nombre de nations trouvées pour Cross-Country Skiing: 8
#   - 8 nations trouvées pour Cross-Country Skiing
#   - Top nations: Norway
# 129, Russia
# 110, Sweden
# 84
# Traitement du sport 18/68: Curling
# Nombre de nations trouvées pour Curling: 8
#   - 8 nations trouvées pour Curling
#   - Top nations: Canada
# 12, Sweden
# 11, Great Britain
# 6
# Traitement du sport 19/68: Cycling
# Nombre de nations trouvées pour Cycling: 8
#   - 8 nations trouvées pour Cycling
#   - Top nations: France
# 108, Great Britain
# 116, Italy
# 69
# Traitement du sport 20/68: Diving
# Nombre de nations trouvées pour Diving: 8
#   - 8 nations trouvées pour Diving
#   - Top nations: China
# 92, United States of America
# 139, Russia
# 35
# Traitement du sport 21/68: Equestrian
# Nombre de nations trouvées pour Equestrian: 8
#   - 8 nations trouvées pour Equestrian
#   - Top nations: Germany
# 100, Sweden
# 45, Great Britain
# 45
# Traitement du sport 22/68: Fencing
# Nombre de nations trouvées pour Fencing: 8
#   - 8 nations trouvées pour Fencing
#   - Top nations: Italy
# 137, France
# 135, Hungary
# 94
# Traitement du sport 23/68: Figure Skating
# Nombre de nations trouvées pour Figure Skating: 8
#   - 8 nations trouvées pour Figure Skating
#   - Top nations: Russia
# 56, United States of America
# 54, Germany
# 24
# Traitement du sport 24/68: Football
# Nombre de nations trouvées pour Football: 8
#   - 8 nations trouvées pour Football
#   - Top nations: United States of America
# 9, Hungary
# 5, Great Britain
# 3
# Traitement du sport 25/68: Freestyle Skiing
# Nombre de nations trouvées pour Freestyle Skiing: 8
#   - 8 nations trouvées pour Freestyle Skiing
#   - Top nations: Canada
# 30, United States of America
# 33, Switzerland
# 13
# Traitement du sport 26/68: Golf
# Nombre de nations trouvées pour Golf: 8
#   - 8 nations trouvées pour Golf
#   - Top nations: United States of America
# 14, Great Britain
# 4, New Zealand
# 3
# Traitement du sport 27/68: Gymnastics
# Nombre de nations trouvées pour Gymnastics: 8
#   - 8 nations trouvées pour Gymnastics
#   - Top nations: Russia
# 244, United States of America
# 126, Japan
# 107
# Traitement du sport 28/68: Handball
# Nombre de nations trouvées pour Handball: 8
#   - 8 nations trouvées pour Handball
#   - Top nations: Russia
# 12, Denmark
# 7, France
# 8
# Traitement du sport 29/68: Hockey
# Nombre de nations trouvées pour Hockey: 8
#   - 8 nations trouvées pour Hockey
#   - Top nations: Netherlands
# 20, India
# 13, Germany
# 16
# Traitement du sport 30/68: Ice Hockey
# Nombre de nations trouvées pour Ice Hockey: 8
#   - 8 nations trouvées pour Ice Hockey
#   - Top nations: Canada
# 23, Russia
# 12, United States of America
# 18
# Traitement du sport 31/68: Jeu de Paume
# Nombre de nations trouvées pour Jeu de Paume: 2
#   - 2 nations trouvées pour Jeu de Paume
#   - Top nations: United States of America
# 1, Great Britain
# 2
# Traitement du sport 32/68: Judo
# Nombre de nations trouvées pour Judo: 8
#   - 8 nations trouvées pour Judo
#   - Top nations: Japan
# 104, France
# 67, Russia
# 43
# Traitement du sport 33/68: Karate
# Nombre de nations trouvées pour Karate: 8
#   - 8 nations trouvées pour Karate
#   - Top nations: Japan
# 3, Spain
# 2, Egypt
# 2
# Traitement du sport 34/68: Lacrosse
# Nombre de nations trouvées pour Lacrosse: 3
#   - 3 nations trouvées pour Lacrosse
#   - Top nations: Canada
# 3, Great Britain
# 1, United States of America
# 1
# Traitement du sport 35/68: Luge
# Nombre de nations trouvées pour Luge: 8
#   - 8 nations trouvées pour Luge
#   - Top nations: Germany
# 87, Italy
# 18, Austria
# 25
# Traitement du sport 36/68: Modern Pentathlon
# Nombre de nations trouvées pour Modern Pentathlon: 8
#   - 8 nations trouvées pour Modern Pentathlon
#   - Top nations: Hungary
# 24, Russia
# 22, Sweden
# 21
# Traitement du sport 37/68: Motorboating
# Nombre de nations trouvées pour Motorboating: 2
#   - 2 nations trouvées pour Motorboating
#   - Top nations: Great Britain
# 2, France
# 1
# Traitement du sport 38/68: Nordic Combined
# Nombre de nations trouvées pour Nordic Combined: 8
#   - 8 nations trouvées pour Nordic Combined
#   - Top nations: Norway
# 35, Germany
# 28, Finland
# 14
# Traitement du sport 39/68: Pelota
# Nombre de nations trouvées pour Pelota: 1
#   - 1 nations trouvées pour Pelota
#   - Top nations: Spain
# 1
# Traitement du sport 40/68: Polo
# Nombre de nations trouvées pour Polo: 8
#   - 8 nations trouvées pour Polo
#   - Top nations: Great Britain
# 6, Argentina
# 2, United States of America / Great Britain
# 1
# Traitement du sport 41/68: Rackets
# Nombre de nations trouvées pour Rackets: 1
#   - 1 nations trouvées pour Rackets
#   - Top nations: Great Britain
# 7
# Traitement du sport 42/68: Rhythmic Gymnastics
# Nombre de nations trouvées pour Rhythmic Gymnastics: 8
#   - 8 nations trouvées pour Rhythmic Gymnastics
#   - Top nations: Russia
# 20, Bulgaria
# 6, Spain
# 3
# Traitement du sport 43/68: Roque
# Nombre de nations trouvées pour Roque: 1
#   - 1 nations trouvées pour Roque
#   - Top nations: United States of America
# 3
# Traitement du sport 44/68: Rowing
# Nombre de nations trouvées pour Rowing: 8
#   - 8 nations trouvées pour Rowing
#   - Top nations: Germany
# 126, United States of America
# 91, Great Britain
# 78
# Traitement du sport 45/68: Rugby
# Nombre de nations trouvées pour Rugby: 8
#   - 8 nations trouvées pour Rugby
#   - Top nations: France
# 5, New Zealand
# 4, Fiji
# 4
# Traitement du sport 46/68: Sailing
# Nombre de nations trouvées pour Sailing: 8
#   - 8 nations trouvées pour Sailing
#   - Top nations: Great Britain
# 65, United States of America
# 62, Norway
# 33
# Traitement du sport 47/68: Shooting
# Nombre de nations trouvées pour Shooting: 8
#   - 8 nations trouvées pour Shooting
#   - Top nations: United States of America
# 121, China
# 77, Russia
# 90
# Traitement du sport 48/68: Short Track
# Nombre de nations trouvées pour Short Track: 8
#   - 8 nations trouvées pour Short Track
#   - Top nations: South Korea
# 53, China
# 37, Canada
# 37
# Traitement du sport 49/68: Skateboarding
# Nombre de nations trouvées pour Skateboarding: 5
#   - 5 nations trouvées pour Skateboarding
#   - Top nations: Japan
# 9, Australia
# 3, Brazil
# 5
# Traitement du sport 50/68: Skeleton
# Nombre de nations trouvées pour Skeleton: 8
#   - 8 nations trouvées pour Skeleton
#   - Top nations: United States of America
# 8, Great Britain
# 9, Germany
# 6
# Traitement du sport 51/68: Ski Jumping
# Nombre de nations trouvées pour Ski Jumping: 8
#   - 8 nations trouvées pour Ski Jumping
#   - Top nations: Norway
# 36, Finland
# 22, Germany
# 25
# Traitement du sport 52/68: Snowboard
# Nombre de nations trouvées pour Snowboard: 8
#   - 8 nations trouvées pour Snowboard
#   - Top nations: United States of America
# 35, Switzerland
# 14, Canada
# 17
# Traitement du sport 53/68: Softball
# Nombre de nations trouvées pour Softball: 5
#   - 5 nations trouvées pour Softball
#   - Top nations: United States of America
# 5, Japan
# 4, Australia
# 4
# Traitement du sport 54/68: Speed Skating
# Nombre de nations trouvées pour Speed Skating: 8
#   - 8 nations trouvées pour Speed Skating
#   - Top nations: Netherlands
# 133, United States of America
# 71, Norway
# 87
# Traitement du sport 55/68: Sport climbing
# Nombre de nations trouvées pour Sport climbing: 8
#   - 8 nations trouvées pour Sport climbing
#   - Top nations: Slovenia
# 2, Poland
# 2, Great Britain
# 1
# Traitement du sport 56/68: Surfing
# Nombre de nations trouvées pour Surfing: 6
#   - 6 nations trouvées pour Surfing
#   - Top nations: United States of America
# 2, Brazil
# 3, France
# 2
# Traitement du sport 57/68: Swimming
# Nombre de nations trouvées pour Swimming: 8
#   - 8 nations trouvées pour Swimming
#   - Top nations: United States of America
# 612, Australia
# 229, Germany
# 194
# Traitement du sport 58/68: Synchronized Swimming
# Nombre de nations trouvées pour Synchronized Swimming: 8
#   - 8 nations trouvées pour Synchronized Swimming
#   - Top nations: Russia
# 10, United States of America
# 10, Canada
# 8
# Traitement du sport 59/68: Table Tennis
# Nombre de nations trouvées pour Table Tennis: 8
#   - 8 nations trouvées pour Table Tennis
#   - Top nations: China
# 66, South Korea
# 20, Japan
# 10
# Traitement du sport 60/68: Taekwondo
# Nombre de nations trouvées pour Taekwondo: 8
#   - 8 nations trouvées pour Taekwondo
#   - Top nations: South Korea
# 25, China
# 13, Iran
# 10
# Traitement du sport 61/68: Tennis
# Nombre de nations trouvées pour Tennis: 8
#   - 8 nations trouvées pour Tennis
#   - Top nations: United States of America
# 41, Great Britain
# 42, France
# 23
# Traitement du sport 62/68: Trampolining
# Nombre de nations trouvées pour Trampolining: 8
#   - 8 nations trouvées pour Trampolining
#   - Top nations: China
# 16, Canada
# 8, Russia
# 4
# Traitement du sport 63/68: Triathlon
# Nombre de nations trouvées pour Triathlon: 8
#   - 8 nations trouvées pour Triathlon
#   - Top nations: Great Britain
# 11, Switzerland
# 6, Germany
# 3
# Traitement du sport 64/68: Tug of war
# Nombre de nations trouvées pour Tug of war: 8
#   - 8 nations trouvées pour Tug of war
#   - Top nations: Great Britain
# 5, United States of America
# 2, Sweden
# 2
# Traitement du sport 65/68: Volleyball
# Nombre de nations trouvées pour Volleyball: 8
#   - 8 nations trouvées pour Volleyball
#   - Top nations: Russia
# 19, Brazil
# 12, United States of America
# 13
# Traitement du sport 66/68: Water Polo
# Nombre de nations trouvées pour Water Polo: 8
#   - 8 nations trouvées pour Water Polo
#   - Top nations: Hungary
# 17, United States of America
# 16, Italy
# 10
# Traitement du sport 67/68: Weightlifting
# Nombre de nations trouvées pour Weightlifting: 8
#   - 8 nations trouvées pour Weightlifting
#   - Top nations: Russia
# 88, China
# 67, United States of America
# 46
# Traitement du sport 68/68: Wrestling
# Nombre de nations trouvées pour Wrestling: 8
#   - 8 nations trouvées pour Wrestling
#   - Top nations: Russia
# 192, United States of America
# 148, Japan
# 87
# Informations sauvegardées pour 68 sports

# %%
import json
import pandas as pd
import re

try:
    with open('sports_medals.json', 'r', encoding='utf-8') as f:
        sports_data = json.load(f)
    print(f"Données chargées : {len(sports_data)} sports trouvés")
except FileNotFoundError:
    print("Fichier sports_medals.json introuvable")
    sports_data = []

pays_dict = {
    'afghanistan': 'af', 'albania': 'al', 'algeria': 'dz', 'argentina': 'ar',
    'armenia': 'am', 'australia': 'au', 'austria': 'at', 'azerbaijan': 'az',
    'bahamas': 'bs', 'belarus': 'by', 'belgium': 'be', 'brazil': 'br',
    'bulgaria': 'bg', 'cameroon': 'cm', 'canada': 'ca', 'chile': 'cl',
    'china': 'cn', 'chinese taipei': 'tw', 'colombia': 'co', 'croatia': 'hr',
    'cuba': 'cu', 'czech republic': 'cz', 'denmark': 'dk', 'egypt': 'eg',
    'estonia': 'ee', 'ethiopia': 'et', 'finland': 'fi', 'france': 'fr',
    'georgia': 'ge', 'germany': 'de', 'great britain': 'gb', 'greece': 'gr',
    'hungary': 'hu', 'india': 'in', 'indonesia': 'id', 'iran': 'ir',
    'ireland': 'ie', 'israel': 'il', 'italy': 'it', 'jamaica': 'jm',
    'japan': 'jp', 'kazakhstan': 'kz', 'kenya': 'ke', 'latvia': 'lv',
    'lithuania': 'lt', 'malaysia': 'my', 'mexico': 'mx', 'mongolia': 'mn',
    'morocco': 'ma', 'netherlands': 'nl', 'new zealand': 'nz', 'nigeria': 'ng',
    'north korea': 'kp', 'norway': 'no', 'pakistan': 'pk', 'poland': 'pl',
    'portugal': 'pt', 'romania': 'ro', 'russia': 'ru', 'serbia': 'rs',
    'slovakia': 'sk', 'slovenia': 'si', 'south africa': 'za', 'south korea': 'kr',
    'soviet union': 'su', 'spain': 'es', 'sweden': 'se', 'switzerland': 'ch',
    'thailand': 'th', 'turkey': 'tr', 'ukraine': 'ua', 'united states': 'us', 
    'united states of america': 'us', 'uzbekistan': 'uz', 'yugoslavia': 'yu'
}

def nettoyer_data_conserver_tous():
    sports_propres = []
    
    for index, sport_orig in enumerate(sports_data):
        sport_name = sport_orig.get('sport', f"Sport inconnu {index}")
        
        if sport_name.startswith("Olympic Medals in Sport "):
            sport_name = sport_name[24:].strip()
            
        nations_propres = []
        
        nations_orig = sport_orig.get('nations', [])
        for nation in nations_orig:
            nation_name_raw = nation.get('nom', '').strip()
            
            match = re.match(r'^(\d+),\s*(.+)$', nation_name_raw)
            if match:
                medal_count = int(match.group(1))
                nation_name = match.group(2).strip().title()
            else:
                nation_name = nation_name_raw.title() if nation_name_raw else ""
                medal_count = 0
            
            if not nation_name:
                continue
                
            medailles = nation.get('medailles', {})
            or_medals = medailles.get('or', 0)
            argent_medals = medailles.get('argent', 0)
            bronze_medals = medailles.get('bronze', 0)
            total_medals = medailles.get('total', 0)
            
            if match and total_medals == 0:
                total_medals = medal_count
                
            if total_medals == 0 and (or_medals > 0 or argent_medals > 0 or bronze_medals > 0):
                total_medals = or_medals + argent_medals + bronze_medals
            
            pays_code = ""
            nom_lower = nation_name.lower()
            if nom_lower in pays_dict:
                pays_code = pays_dict[nom_lower]
            elif 'united states' in nom_lower:
                pays_code = 'us'
            elif 'great britain' in nom_lower:
                pays_code = 'gb'
            
            nation_propre = {
                'nom': nation_name,
                'pays_code': pays_code,
                'or': or_medals,
                'argent': argent_medals,
                'bronze': bronze_medals,
                'total': total_medals
            }
            
            nations_propres.append(nation_propre)
        
        nations_propres = sorted(nations_propres, key=lambda x: x['total'], reverse=True)
        
        sport_propre = {
            'nom': sport_name,
            'nombre_nations': len(nations_propres),
            'nations': nations_propres
        }
        
        sports_propres.append(sport_propre)
    
    print(f"Nombre de sports originaux: {len(sports_data)}")
    print(f"Nombre de sports après nettoyage: {len(sports_propres)}")
    
    print("\nListe complète des sports traités:")
    for i, sport in enumerate(sports_propres):
        print(f"{i+1}. {sport['nom']} - {sport['nombre_nations']} nations")
    
    with open('sports_medals_clean.json', 'w', encoding='utf-8') as f:
        json.dump(sports_propres, f, ensure_ascii=False, indent=4)
    
    print(f"\nFichier 'sports_medals_clean.json' créé avec {len(sports_propres)} sports.")
    
    return sports_propres

sports_clean = nettoyer_data_conserver_tous()
# Out:
# Données chargées : 68 sports trouvés
# Nombre de sports originaux: 68
# Nombre de sports après nettoyage: 68
#
# Liste complète des sports traités:
# 1. Aeronautics - 1 nations
# 2. Alpine Skiing - 8 nations
# 3. Alpinism - 3 nations
# 4. Archery - 8 nations
# 5. Athletics - 8 nations
# 6. Badminton - 8 nations
# 7. Baseball - 7 nations
# 8. Basketball - 8 nations
# 9. Beachvolleyball - 8 nations
# 10. Biathlon - 8 nations
# 11. Bobsledding - 8 nations
# 12. Boxing - 8 nations
# 13. Breaking - 6 nations
# 14. Canoe & Kayaking - 8 nations
# 15. Cricket - 2 nations
# 16. Crocket - 1 nations
# 17. Cross-Country Skiing - 8 nations
# 18. Curling - 8 nations
# 19. Cycling - 8 nations
# 20. Diving - 8 nations
# 21. Equestrian - 8 nations
# 22. Fencing - 8 nations
# 23. Figure Skating - 8 nations
# 24. Football - 8 nations
# 25. Freestyle Skiing - 8 nations
# 26. Golf - 8 nations
# 27. Gymnastics - 8 nations
# 28. Handball - 8 nations
# 29. Hockey - 8 nations
# 30. Ice Hockey - 8 nations
# 31. Jeu de Paume - 2 nations
# 32. Judo - 8 nations
# 33. Karate - 8 nations
# 34. Lacrosse - 3 nations
# 35. Luge - 8 nations
# 36. Modern Pentathlon - 8 nations
# 37. Motorboating - 2 nations
# 38. Nordic Combined - 8 nations
# 39. Pelota - 1 nations
# 40. Polo - 8 nations
# 41. Rackets - 1 nations
# 42. Rhythmic Gymnastics - 8 nations
# 43. Roque - 1 nations
# 44. Rowing - 8 nations
# 45. Rugby - 8 nations
# 46. Sailing - 8 nations
# 47. Shooting - 8 nations
# 48. Short Track - 8 nations
# 49. Skateboarding - 5 nations
# 50. Skeleton - 8 nations
# 51. Ski Jumping - 8 nations
# 52. Snowboard - 8 nations
# 53. Softball - 5 nations
# 54. Speed Skating - 8 nations
# 55. Sport climbing - 8 nations
# 56. Surfing - 6 nations
# 57. Swimming - 8 nations
# 58. Synchronized Swimming - 8 nations
# 59. Table Tennis - 8 nations
# 60. Taekwondo - 8 nations
# 61. Tennis - 8 nations
# 62. Trampolining - 8 nations
# 63. Triathlon - 8 nations
# 64. Tug of war - 8 nations
# 65. Volleyball - 8 nations
# 66. Water Polo - 8 nations
# 67. Weightlifting - 8 nations
# 68. Wrestling - 8 nations
#
# Fichier 'sports_medals_clean.json' créé avec 68 sports.
